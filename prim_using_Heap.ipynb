# %%
from heap import Heap
from graphe import Graph
import numpy as np

# %%
edges = [(0, 1, 3), (1, 2, 7), (2, 3, 6), (3, 4, 8), (4, 7, 9), (7, 8, 1), (5, 6, 0), \
        (0, 5, 7), (1, 5, 10), (2, 8, 1), (8, 5, 16), (8, 6, 5), (2, 7, 3), (3, 7, 13)]

G = Graph(oriented=True, valued=True)
G.load_from_weighted_edges(edges)
H = Heap(type='min')
np.set_printoptions(precision=2)
origin = 0

# %%
# Initialise the distances and predecessors arrays
d = np.ones(G.size_) * np.inf
d[origin] = 0
pi = -np.ones(G.size_)

# Initialise the 'min' heap
tas = zip(G.vertices_, d)
H.init_heap(tas)
H.show()
# Out:
# The Heap :
# |-- Values : [0, 1, 2, 3, 4, 5, 6, 7, 8]
# |-- Priorities : [np.float64(0.0), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________

# %%
"""
    Une implementation efficace de l'algorithme de Prim
    pour trouver un arbre de poids minimum d'un graphe G
    en utilisant un tas de type min, où la priorité dans
    ce tas est défini par le poids d'arrete qui relie le
    sommet en question avec l'ACM, np.inf sinon

    Abréviation:
        ACM : Arbre Couvrant de poids Minimum
"""
verbose = True
ACM = []
while not H.is_empty():
    # récupérer le sommet le plus proche de l'ACM
    curr_vertex, curr_priority = H.dequeue()

    # les successeurs du curr_vertex
    succ_curr_vertex = G.next(curr_vertex)
    if verbose:
        print(f"current vertex :\n{curr_vertex} -> {succ_curr_vertex}")

    for vertex in succ_curr_vertex:
        # On vérifie si le sommet est dans le tas
        # et si on peut améliorer son estimation  
        if vertex in H.positions_ and d[vertex] > G.weight(curr_vertex, vertex):
            # On met a jour la priorité du vertex
            d[vertex] = G.weight(curr_vertex, vertex)
            pi[vertex] = curr_vertex

            # On ajoute l'arc curr_vertex -> vertex a l'ACM
            ACM.append((curr_vertex, vertex, d[vertex]))

            # On met a jour le tas
            H.update_priority(vertex, d[vertex])
            if verbose:
                H.show()
# Out:
# current vertex :
# 0 -> [1 5]
# The Heap :
# |-- Values : [np.int64(1), 8, 2, 3, 4, 5, 6, 7]
# |-- Priorities : [np.float64(3.0), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________
# The Heap :
# |-- Values : [np.int64(1), 8, np.int64(5), 3, 4, 2, 6, 7]
# |-- Priorities : [np.float64(3.0), np.float64(inf), np.float64(7.0), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________
# current vertex :
# 1 -> [2 5]
# The Heap :
# |-- Values : [np.int64(5), 8, np.int64(2), 3, 4, 7, 6]
# |-- Priorities : [np.float64(7.0), np.float64(inf), np.float64(7.0), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________
# current vertex :
# 5 -> [6]
# The Heap :
# |-- Values : [np.int64(6), 8, np.int64(2), 3, 4, 7]
# |-- Priorities : [np.float64(0.0), np.float64(inf), np.float64(7.0), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________
# current vertex :
# 6 -> []
# current vertex :
# 2 -> [3 8 7]
# The Heap :
# |-- Values : [np.int64(3), 4, 7, 8]
# |-- Priorities : [np.float64(6.0), np.float64(inf), np.float64(inf), np.float64(inf)]
# _________
# The Heap :
# |-- Values : [np.int64(8), np.int64(3), 7, 4]
# |-- Priorities : [np.float64(1.0), np.float64(6.0), np.float64(inf), np.float64(inf)]
# _________
# The Heap :
# |-- Values : [np.int64(8), np.int64(3), np.int64(7), 4]
# |-- Priorities : [np.float64(1.0), np.float64(6.0), np.float64(3.0), np.float64(inf)]
# _________
# current vertex :
# 8 -> [5 6]
# current vertex :
# 7 -> [8]
# current vertex :
# 3 -> [4 7]
# The Heap :
# |-- Values : [np.int64(4)]
# |-- Priorities : [np.float64(8.0)]
# _________
# current vertex :
# 4 -> [7]

# %%
print("l'arbre couvrant de poids minimum :", pi)
children = dict()
length = 0
for i, v in enumerate(pi):
    if v == -1:
        continue
    children.setdefault(v, []).append(i)
    length += G.weight(v, i)

print(f"poids de l'arbre {length}")
# Out:
# l'arbre couvrant de poids minimum : [-1.  0.  1.  2.  3.  0.  5.  2.  2.]
# poids de l'arbre 35

# %%
from bigtree import Node

def build_tree(root, tree):
    parent = Node(str(root + 1))
    if tree.get(root) is None:
        return parent
    for c in tree[root]:
        child = build_tree(c, tree)
        child.parent = parent  
    return parent

# %%
build_tree(0, children).vshow()
print(f"poids de l'arbre {length}")
# Out:
#               ┌───┐
#               │ 1 │
#               └─┬─┘
#          ┌──────┴──────┐
#        ┌─┴─┐         ┌─┴─┐
#        │ 2 │         │ 6 │
#        └─┬─┘         └─┬─┘
#          │             │
#        ┌─┴─┐         ┌─┴─┐
#        │ 3 │         │ 7 │
#        └─┬─┘         └───┘
#   ┌──────┼──────┐
# ┌─┴─┐  ┌─┴─┐  ┌─┴─┐
# │ 4 │  │ 8 │  │ 9 │
# └─┬─┘  └───┘  └───┘
#   │
# ┌─┴─┐
# │ 5 │
# └───┘
# poids de l'arbre 35
